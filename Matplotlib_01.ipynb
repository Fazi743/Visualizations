# %% [markdown]
# # Matplotlib for Data Visualization

# %%
# !pip install matplotlib --quiet

# %%
# libraries import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ax = plt.subplots()             # Create a figure containing a single Axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the Axes.
plt.show()

# %%
# df = pd.read_csv("../00_datasets/titanic.csv")
# df.sample(5)
df = sns.load_dataset("exercise")
print(df.head())
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
# bar plot using plt
df['kind'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='kind'>

# %%
# creata a bar plot using matplotlib
plt.bar(df['kind'], df['pulse'], color='maroon')
# Out:
# <BarContainer object of 90 artists>

# %%
# Figure Size
fig = plt.figure(figsize =(7, 4)) # width, height
# creata a bar plot using matplotlib
plt.bar(df['diet'], df['time'], color='green')
# save the plot in png with 300 dpi resolution
# plt.savefig('./01_plots/bar_plot.png', dpi=300)
# save svg file
# plt.savefig('./01_plots/bar_plot_svg.svg', format='svg')

# show the plot
plt.show()

# %%
fig = plt.figure(figsize =(7, 4)) # width, height
plt.scatter(df['pulse'], df['time'], color='maroon')
# label plots
plt.xlabel('Pulse')
plt.ylabel('Time')
plt.title('Pulse vs Time')
plt.show()

# %%
diamonds = sns.load_dataset("diamonds")
print(diamonds.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# creata a bar plot using matplotlib
plt.stem(diamonds['cut'], diamonds['depth'])
# Out:
# <StemContainer object of 3 artists>

# %%
plt.stackplot(diamonds['clarity'], diamonds['price'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
y = [4.8, 5.5, 3.5, 4.6, 6.5, 6.6, 2.6, 3.0,5.5, 1.9]

# plot
fig, ax = plt.subplots()

ax.stairs(y, linewidth=2.5)

ax.set(xlim=(0, 10), xticks=np.arange(1, 11),
       ylim=(0, 10), yticks=np.arange(1, 11))

plt.show()

# %%
plt.hist(diamonds['price'], bins=11, color='red')
# Out:
# (array([24246.,  8991.,  7344.,  4153.,  2526.,  1861.,  1420.,  1108.,
#           871.,   774.,   646.]),
#  array([  326.        ,  2007.54545455,  3689.09090909,  5370.63636364,
#          7052.18181818,  8733.72727273, 10415.27272727, 12096.81818182,
#         13778.36363636, 15459.90909091, 17141.45454545, 18823.        ]),
#  <BarContainer object of 11 artists>)

# %%
# # box plot
# plt.boxplot(df['pclass'], df['age'])

# %%
# !pip install seaborn --quiet

# %%
import seaborn as sns

# %%
fig = plt.figure(figsize =(7, 4)) # width, height
sns.boxplot(data = diamonds, x = 'cut', y='table')
# add labels
plt.xlabel("Cut")
plt.ylabel("Table")
plt.title("Box Plot")
# plt.savefig('./01_plots/box_plot_seaborn.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %%
plt.figure(figsize=(8, 4))  # width=10, height=6 inches
sns.boxenplot(data = diamonds, x = 'cut', y='clarity')
# Out:
# <Axes: xlabel='cut', ylabel='clarity'>

# %%
fig = plt.figure(figsize =(7, 4)) # width, height
# change the colors based on the palette
sns.set_palette("Set1")
sns.barplot(data = diamonds, x = 'clarity', y='carat', hue='cut')
# Out:
# <Axes: xlabel='clarity', ylabel='carat'>

# %%
diamonds = sns.load_dataset("diamonds")
print(diamonds.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
fig = plt.figure(figsize =(7, 4)) # width, height
# change the colors based on the palette
sns.set_palette("Set1")
sns.boxplot(data = diamonds, x = 'cut', y='carat', hue='color')
# Out:
# <Axes: xlabel='cut', ylabel='carat'>

# %%
fig = plt.figure(figsize =(7, 4)) # width, height
# change the colors based on the palette
sns.set_palette("Set1")
sns.boxenplot(data = df, x = 'class', y='age', hue='sex',
              order=['First', 'Second', 'Third'])
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
# Out:
# <Axes: xlabel='carat', ylabel='price'>
